# %%
from ipynb.fs.full.preprocessing_step import get_preprocessed_dataset
import pandas as pd

# %%
# how to implement
# only add below 2 lines

shoppers_data = get_preprocessed_dataset()

# %%
shoppers_data.tail(20)
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 8387        -0.696993                -0.457191      -0.396478
# 11017       -0.696993                -0.457191      -0.396478
# 8388        -0.696993                -0.457191      -0.396478
# 11015       -0.696993                -0.457191      -0.396478
# 8397         1.410394                 0.186293       0.390859
# 11014        0.206173                -0.335566       1.178195
# 8389         2.915670                 1.557410      -0.396478
# 10001       -0.395938                -0.332737       1.965532
# 11010       -0.696993                -0.457191      -0.396478
# 11009       -0.696993                -0.457191      -0.396478
# 11008       -0.094882                -0.211112      -0.396478
# 10003        2.012504                 0.652996       0.390859
# 11005       -0.696993                -0.457191      -0.396478
# 11004        1.711449                 0.450758       1.178195
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
X=shoppers_data.drop(columns=['Revenue'])
y=shoppers_data['Revenue']

model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(13).plot(kind='barh')
plt.show()

# %%
import numpy as np
import seaborn as sns
#get correlations of each features in dataset
corrmat = shoppers_data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(shoppers_data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
